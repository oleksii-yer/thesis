# %%
import analytical as an
import numpy as np
import matplotlib.pyplot as plt
import functions as fn
import num_methods as nm
import ploting as pltin
import analytical as an
import toolset as ts
import utility
from IPython.display import HTML
import importlib
import time

# %%
importlib.reload(an)
importlib.reload(pltin)
importlib.reload(fn)
importlib.reload(nm)
importlib.reload(ts)
importlib.reload(utility)
# Out:
# <module 'utility' from 'c:\\SelfCreated\\Studies\\Thesis\\code\\thesis\\utility.py'>

# %% [markdown]
# ---

# %% [markdown]
# > F - closed, f - meandrum:

# %% [markdown]
# **Unsafe scenario:**

# %%
importlib.reload(an)
importlib.reload(ts)

a = 1
b = 1
tau = 10

mu_range = np.linspace(0.1, 3, 60)

ts.create_diagram_hyst('theoretical', mu_list=mu_range, a=a, b=b, tau=tau, F_type='closed', f_type='meand')
# Out:
# [0.99, 0.98, 0.97, 0.96, 0.9500000000000001, 0.9400000000000001, 0.93, 0.92, 0.91, 0.9, 0.89, 0.88, 0.87, 0.86, 0.85, 0.84, 0.8300000000000001, 0.8200000000000001, 0.81, 0.8, 0.79, 0.78, 0.77, 0.76, 0.75, 0.74, 0.73, 0.72, 0.71, 0.7000000000000001, 0.6900000000000001, 0.68, 0.67, 0.66, 0.65, 0.64, 0.63, 0.62, 0.61, 0.6, 0.59, 0.58, 0.5700000000000001, 0.56, 0.55, 0.54, 0.53, 0.52, 0.51, 0.5, 0.49, 0.48, 0.47000000000000003, 0.46, 0.45, 0.44, 0.43, 0.42, 0.41000000000000003, 0.4, 0.39, 0.38461538461538464, 0.39, 0.4, 0.41000000000000003, 0.42, 0.43, 0.44, 0.45, 0.46, 0.47000000000000003, 0.48, 0.49, 0.5, 0.51, 0.52, 0.53, 0.54, 0.55, 0.56, 0.5700000000000001, 0.58, 0.59, 0.6, 0.61, 0.62, 0.63, 0.64, 0.65, 0.66, 0.67, 0.68, 0.6900000000000001, 0.7000000000000001, 0.71, 0.72, 0.73, 0.74, 0.75, 0.76, 0.77, 0.78, 0.79, 0.8, 0.81, 0.8200000000000001, 0.8300000000000001, 0.84, 0.85, 0.86, 0.87, 0.88, 0.89, 0.9, 0.91, 0.92, 0.93, 0.9400000000000001, 0.9500000000000001, 0.96, 0.97, 0.98, 0.99
# ...

# %%
# Histenesis diagram
importlib.reload(ts)
importlib.reload(nm)

a = 1
b = 1
tau = 10

t0_list = [0]
x0 = 0
y0_list = np.concatenate([np.arange(0, 2, 0.1) * (-1), np.arange(2, 21, 1) * (-1)])
mu_range = np.concatenate([np.arange(0, 0.3, 0.1), np.linspace(0.3, 1, 15), np.arange(1.1, 2.1, 0.1)])
h = 0.01
t_end = 1000

ts.create_diagram_hyst('numerical', t0_list, y0_list, mu_range, a, b, tau, 'closed', 'meand', h, t_end)
# Out:
# [0.45 0.5  0.55 0.6  0.65 0.7  0.75 0.8  0.85 0.9  0.95] [np.float64(3.8500000000000005), np.float64(3.45), np.float64(3.05), np.float64(2.6500000000000004), np.float64(2.25), np.float64(1.9500000000000002), np.float64(1.6500000000000001), np.float64(1.25), np.float64(0.95), np.float64(0.6500000000000001), np.float64(0.15000000000000002)]

# %%
# Histenesis diagram
importlib.reload(ts)
importlib.reload(nm)

a = 1
b = 1
tau = 10

t0_list = [0]
x0 = 0
y0_list = np.concatenate([np.arange(0, 2, 0.1) * (-1), np.arange(2, 21, 1) * (-1)])
mu_range = np.concatenate([np.arange(0, 0.3, 0.1), np.linspace(0.3, 1, 15), np.arange(1.1, 2.1, 0.1)])
h = 0.01
t_end = 1000

ts.create_diagram_hyst('comparison', t0_list, y0_list, mu_range, a, b, tau, 'closed', 'meand', h, t_end)
# Out:
# [0.45 0.5  0.55 0.6  0.65 0.7  0.75 0.8  0.85 0.9  0.95] [np.float64(3.6500000000000004), np.float64(3.25), np.float64(2.8500000000000005), np.float64(2.55), np.float64(2.25), np.float64(1.85), np.float64(1.55), np.float64(1.25), np.float64(0.95), np.float64(0.6500000000000001), np.float64(0.35000000000000003)]
# ...

# %% [markdown]
# **Safe scenario:**

# %%
importlib.reload(an)
importlib.reload(ts)

a = 10
b = 2
tau = 4

mu_range = np.linspace(0.1, 3, 60)

ts.create_diagram_hyst('theoretical', mu_list=mu_range, a=a, b=b, tau=tau, F_type='closed', f_type='meand')

# %%
importlib.reload(ts)
importlib.reload(nm)

a = 10
b = 2
tau = 4

t0_list = [0]
x0 = 0
y0_list = np.concatenate([np.arange(0, 2, 0.1) * (-1), np.arange(2, 21, 1) * (-1)])
mu_range = np.concatenate([np.arange(0, 0.8, 0.1), np.linspace(0.8, 1.3, 10), np.arange(1.4, 2.1, 0.1)])
h = 0.01
t_end = 1000

ts.create_diagram_hyst('numerical', t0_list, y0_list, mu_range, a, b, tau, 'closed', 'meand', h, t_end)
# Out:
# [] []

# %%
a = 10
b = 2
tau = 4

print(an.compute_roots_t0(1, a, b, tau, 'meand', tcr_filter=False))
print(an.compute_tcr(1, a, b, tau, 'meand'))
# Out:
# [-6.  0.]
# 0.0

# %%
# Histenesis diagram
importlib.reload(ts)
importlib.reload(nm)

a = 10
b = 2
tau = 4

t0_list = [0]
x0 = 0
y0_list = np.concatenate([np.arange(0, 2, 0.1) * (-1), np.arange(2, 21, 1) * (-1)])
mu_range = np.concatenate([np.arange(0.6, 0.8, 0.1), np.linspace(0.8, 1.3, 10), np.arange(1.4, 2.1, 0.1)])
h = 0.01
t_end = 1000

ts.create_diagram_hyst('comparison', t0_list, y0_list, mu_range, a, b, tau, 'closed', 'meand', h, t_end)
# Out:
# [] []

# %%
print(an.compute_roots_t0(1.2, 10, 2, 4, 'meand', tcr_filter=False))
print(an.compute_tcr(1.2, 10, 2, 4, 'meand'))
print(an.compute_y0(1.5, 1.2, 2, 4, 'meand'))
print(an.compute_y0(-0.5, 1.2, 2, 4, 'meand'))
# Out:
# [-6.51188458  0.51188458]
# -0.5
# 2.8
# -1.9999999999999998

# %% [markdown]
# ---

# %% [markdown]
# > F - closed, f - sin:

# %% [markdown]
# **Unsafe scenario:**

# %%
importlib.reload(an)
# Out:
# <module 'analytical' from 'c:\\SelfCreated\\Studies\\Thesis\\code\\thesis\\analytical.py'>

# %%
a = 1
b = 1
tau = 10

mu_range = np.linspace(0.1, 3, 60)
ts.create_diagram_hyst('theoretical', mu_list=mu_range, a=a, b=b, tau=tau, F_type='closed', f_type='sin')
# Out:
# [1.28, 1.27, 1.26, 1.25, 1.24, 1.23, 1.22, 1.21, 1.2, 1.19, 1.18, 1.17, 1.16, 1.1500000000000001, 1.1400000000000001, 1.1300000000000001, 1.12, 1.11, 1.1, 1.09, 1.08, 1.07, 1.06, 1.05, 1.04, 1.03, 1.02, 1.01, 1.0, 0.99, 0.98, 0.97, 0.96, 0.9500000000000001, 0.9400000000000001, 0.93, 0.92, 0.91, 0.9, 0.89, 0.88, 0.87, 0.86, 0.85, 0.84, 0.8300000000000001, 0.8200000000000001, 0.81, 0.8, 0.79, 0.78, 0.77, 0.76, 0.75, 0.74, 0.73, 0.72, 0.71, 0.7000000000000001, 0.6900000000000001, 0.68, 0.67, 0.66, 0.65, 0.64, 0.63, 0.62, 0.61, 0.6, 0.59, 0.58, 0.5700000000000001, 0.56, 0.55, 0.54, 0.53, 0.52, 0.51, 0.5, 0.49, 0.48, 0.4707940541566164, 0.48, 0.49, 0.5, 0.51, 0.52, 0.53, 0.54, 0.55, 0.56, 0.5700000000000001, 0.58, 0.59, 0.6, 0.61, 0.62, 0.63, 0.64, 0.65, 0.66, 0.67, 0.68, 0.6900000000000001, 0.7000000000000001, 0.71, 0.72, 0.73, 0.74, 0.75, 0.76, 0.77, 0.78, 0.79, 0.8, 0.81, 0.8200000000000001, 0.8300000000000001, 0.84, 0.85, 0.86, 0.87, 0.88, 0.89, 0.9, 0.91, 0.92, 0.93, 0.94000000000000
# ...

# %%
a = 1
b = 1
tau = 10

t0_list = [0]
x0 = 0
y0_list = np.concatenate([np.arange(0, 2, 0.1) * (-1), np.arange(2, 21, 1) * (-1)])
mu_range = np.concatenate([np.arange(0.1, 0.4, 0.1), np.linspace(0.4, 1.3, 20), np.arange(1.4, 2.1, 0.1)])
h = 0.01
t_end = 1000

ts.create_diagram_hyst('numerical', t0_list, y0_list, mu_range, a, b, tau, 'closed', 'sin', h, t_end)
# Out:
# [0.54210526 0.58947368 0.63684211 0.68421053 0.73157895 0.77894737
#  0.82631579 0.87368421 0.92105263 0.96842105 1.01578947 1.06315789
#  1.11052632 1.15789474] [np.float64(4.550000000000001), np.float64(4.35), np.float64(4.050000000000001), np.float64(3.75), np.float64(3.55), np.float64(3.3500000000000005), np.float64(3.05), np.float64(2.8500000000000005), np.float64(2.6500000000000004), np.float64(2.45), np.float64(2.25), np.float64(2.05), np.float64(1.85), np.float64(1.6500000000000001)]

# %%
a = 1
b = 1
tau = 10
mu = 0.5421052631578948

print(an.compute_roots_t0(mu, a, b, tau, 'sin'))
print('y0 =', [an.compute_y0(t, mu, b, tau, 'sin') for t in an.compute_roots_t0(mu, a, b, tau, 'sin')])
print('mu0 =', an.compute_mu0(a, b, tau, 'sin'))
print('t_cr=', an.compute_tcr(mu, a, b, tau, 'sin'))
# print('y0 =', [an.compute_y0(t, mu, b, tau, 'sin') for t in an.compute_tcr(mu, a, b, tau, 'sin')])
print(np.sqrt(1 + ((a/b - tau/2)/(a*np.pi/(2*b)))**2)*an.compute_mu0(a, b, tau, 'sin'))
print(np.sqrt(1 + ((a/b - tau/2)/(a*np.pi/(2*b)))**2)*an.compute_mu0(a, b, tau, 'sin'))
# Out:
# [2.37994474 5.68221143]
# y0 = [np.float64(3.7346927970418826), np.float64(5.367005579420871)]
# mu0 = 0.4707940541566164
# t_cr= []
# 1.2879944251000535
# 1.2879944251000535

# %%
# Histenesis diagram
importlib.reload(ts)
importlib.reload(nm)

a = 1
b = 1
tau = 10

t0_list = [0]
x0 = 0
y0_list = np.concatenate([np.arange(0, 2, 0.1) * (-1), np.arange(2, 21, 1) * (-1)])
mu_range = np.concatenate([np.arange(0.1, 0.4, 0.1), np.linspace(0.4, 1.3, 20), np.arange(1.4, 2.1, 0.1)])
h = 0.01
t_end = 1000

ts.create_diagram_hyst('comparison', t0_list, y0_list, mu_range, a, b, tau, 'closed', 'sin', h, t_end)
# Out:
# [0.54210526 0.58947368 0.63684211 0.68421053 0.73157895 0.77894737
#  0.82631579 0.87368421 0.92105263 0.96842105 1.01578947 1.06315789
#  1.11052632 1.15789474] [np.float64(3.75), np.float64(3.45), np.float64(3.25), np.float64(3.05), np.float64(2.8500000000000005), np.float64(2.6500000000000004), np.float64(2.45), np.float64(2.25), np.float64(2.1500000000000004), np.float64(1.9500000000000002), np.float64(1.85), np.float64(1.6500000000000001), np.float64(1.4500000000000002), np.float64(1.35)]
# ...

# %% [markdown]
# **Safe scenario:**

# %%
importlib.reload(an)
importlib.reload(ts)

a = 10
b = 2
tau = 4

mu_range = np.linspace(0.1, 3, 60)

ts.create_diagram_hyst('theoretical', mu_list=mu_range, a=a, b=b, tau=tau, F_type='closed', f_type='sin')

# %%
a = 10
b = 2
tau = 4

t0_list = [0]
x0 = 0
y0_list = np.concatenate([np.arange(0, 2, 0.1) * (-1), np.arange(2, 21, 1) * (-1)])
mu_range = np.concatenate([np.arange(0, 1.3, 0.1), np.linspace(1.3, 1.8, 10), np.arange(1.8, 2.6, 0.1)])
h = 0.01
t_end = 1000

ts.create_diagram_hyst('numerical', t0_list, y0_list, mu_range, a, b, tau, 'closed', 'sin', h, t_end)
# Out:
# [] []
# c:\SelfCreated\Studies\Thesis\code\thesis\toolset.py:299: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.colorbar(sc, cax=cbar_ax, label=r'$y_0$ values') # Make numerical function return sc!!!

# %%
print(an.compute_mu0(10, 2, 4, 'sin'))
# Out:
# 1.522216991373643

# %%
a = 10
b = 2
tau = 4

t0_list = [0]
x0 = 0
y0_list = np.concatenate([np.arange(0, 2, 0.1) * (-1), np.arange(2, 21, 1) * (-1)])
mu_range = np.concatenate([np.arange(0.9, 1.3, 0.1), np.linspace(1.3, 1.8, 10), np.arange(1.8, 2.6, 0.1)])
h = 0.01
t_end = 1000

ts.create_diagram_hyst('comparison', t0_list, y0_list, mu_range, a, b, tau, 'closed', 'sin', h, t_end)
# Out:
# [] []

# %% [markdown]
# ---

# %% [markdown]
# > F - open, f - meand:

# %% [markdown]
# **Unsafe scenario:**

# %%
importlib.reload(ts)
importlib.reload(nm)

a = 1
b = 1
tau = 10

t0_list = [0]
x0 = 0
y0_list = np.concatenate([np.arange(0, 2, 0.1) * (-1), np.arange(2, 21, 1) * (-1)])
mu_range = np.concatenate([np.arange(0.1, 0.3, 0.1), np.linspace(0.3, 0.8, 15), np.arange(0.9, 2.1, 0.1)])
h = 0.01
t_end = 1000

ts.create_diagram_hyst('numerical', t0_list, y0_list, mu_range, a, b, tau, 'open', 'meand', h, t_end)
# Out:
# [0.40714286 0.44285714 0.47857143 0.51428571 0.55       0.58571429
#  0.62142857 0.65714286 0.69285714] [np.float64(3.55), np.float64(3.25), np.float64(2.95), np.float64(2.6500000000000004), np.float64(2.3500000000000005), np.float64(2.05), np.float64(1.75), np.float64(1.4500000000000002), np.float64(1.1500000000000001)]

# %% [markdown]
# **Safe scenario:**

# %%
importlib.reload(ts)
importlib.reload(nm)

a = 10
b = 2
tau = 4

t0_list = [0]
x0 = 0
y0_list = np.concatenate([np.arange(0, 2, 0.1) * (-1), np.arange(2, 21, 1) * (-1)])
mu_range = np.concatenate([np.arange(0.1, 0.8, 0.1), np.linspace(0.8, 1.3, 15), np.arange(1.4, 2.1, 0.1)])
h = 0.01
t_end = 1000

ts.create_diagram_hyst('numerical', t0_list, y0_list, mu_range, a, b, tau, 'open', 'meand', h, t_end)
# Out:
# [] []

# %% [markdown]
# ---

# %% [markdown]
# > F - open, f - sin:

# %% [markdown]
# **Unsafe scenario:**

# %%
importlib.reload(ts)
importlib.reload(nm)

a = 1
b = 1
tau = 10

t0_list = [0]
x0 = 0
y0_list = np.concatenate([np.arange(0, 2, 0.1) * (-1), np.arange(2, 21, 1) * (-1)])
mu_range = np.concatenate([np.arange(0.1, 0.4, 0.1), np.linspace(0.4, 1.1, 15), np.arange(1.2, 2.1, 0.1)])
h = 0.01
t_end = 1000

ts.create_diagram_hyst('numerical', t0_list, y0_list, mu_range, a, b, tau, 'open', 'sin', h, t_end)
# Out:
# [0.5  0.55 0.6  0.65 0.7  0.75 0.8  0.85 0.9 ] [np.float64(3.55), np.float64(3.1500000000000004), np.float64(2.8500000000000005), np.float64(2.6500000000000004), np.float64(2.3500000000000005), np.float64(2.1500000000000004), np.float64(1.85), np.float64(1.55), np.float64(1.1500000000000001)]

# %% [markdown]
# **Safe scenario:**

# %%
importlib.reload(ts)
importlib.reload(nm)

a = 10
b = 2
tau = 4

t0_list = [0]
x0 = 0
y0_list = np.concatenate([np.arange(0, 2, 0.1) * (-1), np.arange(2, 21, 1) * (-1)])
mu_range = np.concatenate([np.arange(0.1, 0.8, 0.1), np.linspace(0.8, 1.3, 15), np.arange(1.4, 2.1, 0.1)])
h = 0.01
t_end = 1000

ts.create_diagram_hyst('numerical', t0_list, y0_list, mu_range, a, b, tau, 'open', 'sin', h, t_end)
# Out:
# [] []

# %%
importlib.reload(ts)
importlib.reload(nm)

a = 1
b = 1
tau = 10

t0_list = [0]
x0 = 0
y0_list = np.concatenate([np.arange(0, 2, 0.1) * (-1), np.arange(2, 21, 1) * (-1)])
mu_range = np.concatenate([np.arange(0.1, 0.4, 0.1), np.linspace(0.4, 2, 20), np.arange(2.1, 2.6, 0.1)])
h = 0.01
t_end = 1000

ts.create_diagram_hyst('numerical', t0_list, y0_list, mu_range, a, b, tau, 'tanh', 'sin', h, t_end)
# Out:
# [0.56842105 0.65263158 0.73684211 0.82105263 0.90526316] [np.float64(3.25), np.float64(2.75), np.float64(2.3500000000000005), np.float64(1.9500000000000002), np.float64(1.4500000000000002)]

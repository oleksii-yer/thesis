# %%
import analytical as an
import numpy as np
import matplotlib.pyplot as plt
import functions as fn
import num_methods as nm
import ploting as pltin
import analytical as an
import toolset as ts
import utility
from IPython.display import HTML
import importlib
import time

# %%
importlib.reload(an)
importlib.reload(pltin)
importlib.reload(fn)
importlib.reload(nm)
importlib.reload(ts)
importlib.reload(utility)
# Out:
# <module 'utility' from 'c:\\SelfCreated\\Studies\\Thesis\\code\\thesis\\utility.py'>

# %% [markdown]
# ---

# %% [markdown]
# ### Setup of parameters and functions:

# %%
a = 1
b = 1
tau = 10
phi = 0

# %% [markdown]
# ---

# %% [markdown]
# ## Hystenesis plots:

# %% [markdown]
# > F - collapsed, f - meandrum:

# %%
# Histenesis diagram
importlib.reload(ts)
t0_list = np.linspace(0, 2*tau, 5)[:-1]
x0 = 0
y0_list = np.arange(0, 21, 2) * (-1)
mu_range = np.concatenate([np.arange(0, 0.3, 0.1), np.linspace(0.3, 0.5, 10), np.arange(0.5, 2.1, 0.1)])
h = 0.005  # Time step
t_end = 1000  # End time

ts.create_diagram_point(t0_list, y0_list, mu_range, a, b, tau, fn.F_collapsed, fn.f_meand, 0, h, t_end)

# %%
# Histenesis diagram
importlib.reload(ts)
t0_list = np.linspace(0, 2*tau, 5)[:-1]
x0 = 0
y0_list = np.arange(0, 21, 2) * (-1)
mu_range = np.concatenate([np.arange(0, 0.3, 0.1), np.linspace(0.3, 0.5, 10), np.arange(0.5, 2.1, 0.1)])
h = 0.005  # Time step
t_end = 500  # End time

ts.create_diagram_point(t0_list, y0_list, mu_range, a, b, tau, fn.F_collapsed, fn.f_meand, 0, h, t_end)

# %%
# Histenesis diagram
importlib.reload(ts)
t0_list = np.linspace(0, 2*tau, 5)[:-1]
x0 = 0
y0_list = np.arange(0, 71, 2) * (-1)
mu_range = np.concatenate([np.arange(0, 0.3, 0.1), np.linspace(0.3, 0.5, 10), np.arange(0.5, 2.1, 0.1)])
h = 0.005  # Time step
t_end = 1000  # End time

ts.create_diagram_point(t0_list, y0_list, mu_range, a, b, tau, 'collapsed', 'meand', 0, h, t_end)

# %% [markdown]
# > F - collapsed, f- sin:

# %%
# Histenesis diagram
importlib.reload(ts)
t0_list = np.linspace(0, 2*tau, 5)[:-1]
x0 = 0
y0_list = np.arange(0, 21, 2) * (-1)
mu_range = np.concatenate([np.arange(0, 0.3, 0.1), np.linspace(0.3, 0.5, 10), np.arange(0.5, 2.1, 0.1)])
h = 0.005  # Time step
t_end = 1000  # End time

ts.create_diagram_point(t0_list, y0_list, mu_range, a, b, tau, fn.F_collapsed, fn.sin, 0, h, t_end)

# %% [markdown]
# > F - open, f- meandrum:

# %%
# Histenesis diagram
importlib.reload(ts)
t0_list = np.linspace(0, 2*tau, 5)[:-1]
x0 = 0
y0_list = np.arange(0, 21, 2) * (-1)
mu_range = np.concatenate([np.arange(0, 0.3, 0.1), np.linspace(0.3, 0.5, 10), np.arange(0.5, 2.1, 0.1)])
h = 0.005  # Time step
t_end = 1000  # End time

ts.create_diagram_point(t0_list, y0_list, mu_range, a, b, tau, 'open', 'meand', 0, h, t_end)

# %%
# Eigenvaleus
importlib.reload(ts)
a = 1
b = 1
tau = 10
phi = 0
t0 = 0
h = 0.005
t_end = 1000
mu = 0.8
e1 = 0.1
e2 = -0.1

print(ts.preturbation_eigen(e1, e2, t0, h, t_end, 'collapsed', 'meand', a, b, phi, mu, tau))
# Out:
# 0 -8.9
# -0.1 -9.0
# [ 0.   0.1 -0.1  0. ]
# EigResult(eigenvalues=array([-0.01123596,  1.        ]), eigenvectors=array([[0.        , 0.70710678],
#        [1.        , 0.70710678]]))

# %%
# Histenesis diagram
importlib.reload(an)
importlib.reload(pltin)
importlib.reload(fn)
importlib.reload(nm)
importlib.reload(ts)
t0_list = np.linspace(0, 2*tau, 5)[:-1]
x0 = 0
y0_list = np.arange(0, 80, 2) * (-1)
mu_range = np.concatenate([np.arange(0, 0.3, 0.1), np.linspace(0.3, 0.5, 10), np.arange(0.5, 2.1, 0.1)])
h = 0.005  # Time step
t_end = 1000  # End time

ts.create_diagram_point(t0_list, y0_list, mu_range, fn.f_meand, fn.F_collapsed, a, b, tau, phi, h, t_end)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 6
#       4 importlib.reload(fn)
#       5 importlib.reload(nm)
# ----> 6 importlib.reload(ts)
#       7 t0_list = np.linspace(0, 2*tau, 5)[:-1]
#       8 x0 = 0
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:131, in reload(module)
#     129 if spec is None:
#     130     raise ModuleNotFoundError(f"spec not found for the module {name!r}", name=name)
# --> 131 _bootstrap._exec(spec, module)
#     132 # The module may have replaced itself in sys.modules!
#     133 return sys.modules[name]
#
# File <frozen importlib._bootstrap>:860, in _exec(spec, module)
#
# File <frozen importlib._bootstrap_external>:994, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# ...

# %%
# Histenesis diagram
importlib.reload(ts)
importlib.reload(nm)
t0_list = [0]
x0 = 0
y0_list = np.arange(0, 21, 2) * (-1)
mu_range = np.concatenate([np.arange(0, 0.3, 0.1), np.linspace(0.3, 0.5, 10), np.arange(0.5, 2.1, 0.1)])
h = 0.005
t_end = 1000

start_time = time.time()
ts.create_diagram_point_gpu(t0_list, y0_list, mu_range, a, b, tau, fn.F_collapsed, fn.f_meand, 0, h, t_end)
np_time = time.time() - start_time
print(np_time)
# Out:
# <class 'numba.cuda.cudadrv.devicearray.DeviceNDArray'>
# t0 shape: ()
# c:\Users\ASUS\AppData\Local\pypoetry\Cache\virtualenvs\thesis-O1twqRCg-py3.12\Lib\site-packages\numba\cuda\dispatcher.py:536: NumbaPerformanceWarning: Grid size 2 will likely result in GPU under-utilization due to low occupancy.
#   warn(NumbaPerformanceWarning(msg))
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# Cell In[6], line 12
#       9 t_end = 1000
#      11 start_time = time.time()
# ---> 12 ts.create_diagram_point_gpu(t0_list, y0_list, mu_range, a, b, tau, fn.F_collapsed, fn.f_meand, 0, h, t_end)
#      13 np_time = time.time() - start_time
#      14 print(np_time)
#
# File c:\SelfCreated\Studies\Thesis\code\thesis\toolset.py:133, in create_diagram_point_gpu(t0_list, y0_list, mu_list, a, b, tau, F, f, phi, h, t_end)
#     130 ax = np.ravel(ax) if num_plots > 1 else [ax]
# ...

# %%
# Histenesis diagram
importlib.reload(ts)
t0_list = [0]
x0 = 0
y0_list = np.arange(0, 21, 2) * (-1)
mu_range = np.concatenate([np.arange(0, 0.3, 0.1), np.linspace(0.3, 0.5, 10), np.arange(0.5, 2.1, 0.1)])
h = 0.005
t_end = 1000

start_time = time.time()
ts.create_diagram_point123(t0_list, y0_list, mu_range, a, b, tau, fn.F_collapsed, fn.f_meand, 0, h, t_end)
np_time = time.time() - start_time
print(np_time)
# Out:
# 836.7548742294312

# %%
import cupy as cp
import numpy as np
import time

# Create large arrays with NumPy and CuPy
size = 10**8  # Array size for testing

# Create arrays
np_array = np.random.rand(size)
cp_array = cp.random.rand(size)

# Measure time for NumPy operation
start_time = time.time()
np_sum = np.sum(np_array)
np_time = time.time() - start_time
print(f"NumPy sum took: {np_time:.6f} seconds")

# Measure time for CuPy operation (on GPU)
start_time = time.time()
cp_sum = cp.sum(cp_array)
cp_time = time.time() - start_time
print(f"CuPy sum took: {cp_time:.6f} seconds")

# Transfer the result back to CPU if needed
cp_sum_cpu = cp_sum.get()

# Compare results
print(f"NumPy sum: {np_sum}")
print(f"CuPy sum: {cp_sum_cpu}")
# Out:
# NumPy sum took: 0.104789 seconds
# CuPy sum took: 0.000000 seconds
# NumPy sum: 50001147.908950806
# CuPy sum: 49998642.21899665
